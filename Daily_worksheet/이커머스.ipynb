# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 8
#       4
#       5 FILE_PATH = pd.read_excel(r"C:\Users\usm95\TIL-KANT-Sparta\Daily_worksheet\이커머스 (2).xlsx")      # ← 본인 경로로 수정
#       6 CACHE_PATH = "raw_cache.pkl"     # 2회차부터 엑셀 재파싱 생략 (로딩 40초 → 1초)
#       7 SAVE_PLOTS = True                # 그래프 PNG 저장 여부
# ----> 8 OUT_DIR = Path("output")
#       9
#      10 pd.set_option("display.width", 200)
#      11 pd.set_option("display.max_columns", 30)
#
# NameError: name 'Path' is not defined

# %%
# 1. 엑셀 파일 불러오기 (같은 폴더에 있으므로 파일명만 지정)
df = pd.read_excel("이커머스 (2).xlsx")

# 2. customerid 고유값 확인 (대소문자/언더바 구분 필요 - 예: customerid, customer_id, CustomerID 등)
# 고유값 목록 출력
print("Customer ID 고유값 목록:")
print(df["Customer ID"].unique())

# 고유값 개수 출력
print("\n총 고객 수:", df["Customer ID"].nunique())
# Out:
# Customer ID 고유값 목록:
# [13085. 13078. 15362. ... 12942. 13369. 15211.]
#
# 총 고객 수: 4383
