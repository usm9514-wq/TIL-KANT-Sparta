# %%
with open("work_log.txt", "w", encoding="utf-8") as file:
    file.write("고객 문의 확인 완료\n")
    file.write("주간 보고서 작성 완료\n")

    print("업무 기록 저장 완료")
# Out:
# 업무 기록 저장 완료

# %%
with open("todo.txt", "a", encoding="utf-8") as file:
    file.write("Listen to Python lecture\n")
    file.write("Do practice questions\n")
    pass

# %%
import csv

with open("employee.csv", "w", encoding='utf-8', newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["name"])
# Out:
#   Cell In[8], line 3
#     with open("employee.csv", )
#                                ^
# SyntaxError: expected ':'

# %%
import json

json_data = '{"name": "민수", "point": 1500, "grade": "VIP"}'

user = json.loads(json_data)

print(type(user))
print(user["name"])
print(user["point"])
# Out:
# <class 'dict'>
# 민수
# 1500

# %%
import pandas as pd
import numpy as np


df = pd.read_csv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3
#       4
#
# ModuleNotFoundError: No module named 'pandas'
